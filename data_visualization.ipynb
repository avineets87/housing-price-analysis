# %%
# loading libraries 
import pandas as pd
import numpy as np

# %%
#read and display data
df1 =pd.read_csv("resources/NY-House-Dataset_suburb.csv")
df2 = pd.read_csv('resources/housing_geocode_extraction.csv')
df1.drop_duplicates()
df2.drop_duplicates()
data = pd.merge(df1, df2, left_on=['LATITUDE', 'LONGITUDE'], right_on=['LATITUDE', 'LONGITUDE'], how='inner')
data.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0                  Brokered by ANNE LOPA REAL ESTATE      House for sale
# 1                  Brokered by ANNE LOPA REAL ESTATE      House for sale
# 2                                Brokered by Serhant      Condo for sale
# 3                                Brokered by Serhant      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#         PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0  2147483647     7   6.000000       10000.0
# 1  2147483647     7   6.000000       10000.0
# 2   195000000     7  10.000000       17545.0
# 3   195000000     7  10.000000       17545.0
# 4    65000000     3   2.373861       15200.0
#
#                                              ADDRESS             STATE_x  \
# 0                                 6659-6675 Amboy Rd  New York, NY 10309
# 1                                 6659-6675 Amboy Rd  New York, NY 10309
# 2  Central Park Tower Penthouse-217 W 57th New Yo...  New York, NY 10019
# 3  Central Park Tower Penthouse-217 W 57th New Yo...  New York, NY 10019
# 4                                        4 E 79th St  New York, NY 10075
#
#                                         MAIN_ADDRESS  \
# 0               6659-6675 Amboy RdNew York, NY 10309
# 1               6659-6675 Amboy RdNew York, NY 10309
# 2  Central Park Tower Penthouse-217 W 57th New Yo...
# 3  Central Park Tower Penthouse-217 W 57th New Yo...
# 4                      4 E 79th StNew York, NY 10075
#
#   ADMINISTRATIVE_AREA_LEVEL_2  ...         suburb         LONG_NAME  \
# 0               United States  ...  Staten Island        Amboy Road
# 1               United States  ...  Staten Island        Amboy Road
# 2               United States  ...      Manhattan  West 57th Street
# 3               United States  ...      Manhattan  West 57th Street
# 4               United States  ...      Manhattan  East 79th Street
#
#                              FORMATTED_ADDRESS   LATITUDE  LONGITUDE  \
# 0  6659 Amboy Rd, Staten Island, NY 10309, USA  40.518484 -74.224418
# 1  6659 Amboy Rd, Staten Island, NY 10309, USA  40.518484 -74.224418
# 2       217 W 57th St, New York, NY 10019, USA  40.766393 -73.980991
# 3       217 W 57th St, New York, NY 10019, USA  40.766393 -73.980991
# 4         4 E 79th St, New York, NY 10075, USA  40.776561 -73.963317
#
#     STATE_y  LOCALITY_y  SUBLOCALITY_y POSTCODE     PROPERTY_CATEGORY
# 0  New York    New York  Staten Island    10309   building.commercial
# 1  New York    New York  Staten Island    10309   building.commercial
# 2  New York    New York      Manhattan    10019  building.residential
# 3  New York    New York      Manhattan    10019  building.residential
# 4  New York    New York      Manhattan    10075              building
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
data.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.describe()
#
# NameError: name 'data' is not defined
