# %% [markdown]
# # Loading and enriching data

# %%
import pandas as pd
import requests
import time

# %%
df = pd.read_csv('./resources/NY-House-Dataset.csv')

# %%
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# 2                                   620 Sinclair Ave  Staten Island, NY 10312
# 3                            2 E 55th St Unit 908W33      Manhattan, NY 10022
# 4                                        5 E 64th St       New York, NY 10065
#
#                                         MAIN_ADDRESS  \
# 0             2 E 55th St Unit 803New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...
# 2            620 Sinclair AveStaten Island, NY 10312
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022
# 4                      5 E 64th StNew York, NY 10065
#
#   ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY       STREET_NAME  \
# 0             New York County  New York        Manhattan  East 55th Street
# 1               United States  New York  New York County          New York
# 2               United States  New York  Richmond County     Staten Island
# 3               United States  New York  New York County          New York
# 4               United States  New York  New York County          New York
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 1  West 57th Street             217 W 57th St, New York, NY 10019, USA
# 2   Sinclair Avenue     620 Sinclair Ave, Staten Island, NY 10312, USA
# 3  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 4  East 64th Street               5 E 64th St, New York, NY 10065, USA
#
#     LATITUDE  LONGITUDE
# 0  40.761255 -73.974483
# 1  40.766393 -73.980991
# 2  40.541805 -74.196109
# 3  40.761398 -73.974613
# 4  40.767224 -73.969856

# %%
results = []

# Your OpenCage API key
api_key = 'b8568cb9afc64fad861a69edbddb2658'  # Replace with your actual API key

# Loop through each row in the DataFrame
for index, row in df.iterrows():
    lat = row['LATITUDE']  # Replace with your latitude column name
    lon = row['LONGITUDE']  # Replace with your longitude column name

    # Make the API call
    #https://api.geoapify.com/v1/geocode/reverse?lat=40.618103&lon=-74.0369047&format=json&apiKey=b8568cb9afc64fad861a69edbddb2658
    url = f'https://api.geoapify.com/v1/geocode/reverse?lat={lat}&lon={lon}&format=json&apiKey={api_key}'
   
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        print(data)
        if data['results']:
            # Extract relevant information
            suburb = data['results'][0]['suburb'] if 'suburb' in data['results'][0] else None
            postcode = data['results'][0]['postcode']
            category = data['results'][0]['category'] if 'category' in data['results'][0] else None
            result_type = data['results'][0]['result_type'] if 'result_type' in data['results'][0] else None
            state = data['results'][0]['state']
            city = data['results'][0]['city']

            additional_data = {
                'lat': lat,
                'lon': lon,
                'suburb': suburb,
                'postcode': postcode,
                'category': category,
                'result_type': result_type,
                'state': state,
                'city': city,
            }
            results.append(additional_data)
        else:
            print(f"No results for lat: {lat}, lon: {lon}")
    else:
        print(f"Error: {response.status_code} for lat: {lat}, lon: {lon}")

    # Sleep to avoid hitting API rate limits
    # time.sleep(1)  # Adjust based on API limits

# Create a DataFrame from results
results_df = pd.DataFrame(results)

# Save to a new CSV file
results_df.to_csv('./resources/housing_additional_data_file.csv', index=False)  # Replace with your desired output file name
# Out:
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'Astor Court', 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'county': 'New York County', 'city': 'New York', 'postcode': '10022', 'district': 'Manhattan Community Board 5', 'suburb': 'Manhattan', 'street': 'East 55th Street', 'housenumber': '2', 'lon': -73.9744256, 'lat': 40.761318, 'state_code': 'NY', 'distance': 8.530679660519068, 'result_type': 'amenity', 'formatted': 'Astor Court, 2 East 55th Street, New York, NY 10022, United States of America', 'address_line1': 'Astor Court', 'address_line2': '2 East 55th Street, New York, NY 10022, United States of America', 'category': 'catering.restaurant', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8Q26G+G6', 'plus_code_short': 'Q26G+G6 New York, New York County, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 9.615793062435909}, 'place_id': '51a71831fd5c7e52c05996ed43de72614440f00103f901179fc94101000000c0020192030b4173746f7220436f757274e203236f70656e7374726565746d61703a76656e75653a6e6f64652f35333938363939373939', 'bbox': {'lon1': -73.9744756, 'lat1': 40.761268, 'lon2': -73.9743756, 'lat2': 40.761368}}], 'query': {'lat': 40.761255, 'lon': -73.9744834, 'plus_code': '87G8Q26G+G6'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'Central Park Tower', 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'county': 'New York County', 'city': 'New York', 'postcode': '10019', 'district': 'Manhattan Community Board 5', 'suburb': 'Manhattan', 'street': 'West 57th Street', 'housenumber': '225', 'lon': -73.9809958617897, 'lat': 40.76638955, 'state_code': 'NY', 'distance': 0, 'result_type': 'amenity', 'formatted': 'Central Park Tower, 225 West 57th Street, New York, NY 10019, United States of America', 'address_line1': 'Central Park Tower', 'address_line2': '225 West 57th Street, New York, NY 10019, United States of America', 'category': 'building.residential', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8Q289+HJ', 'plus_code_short': 'Q289+HJ New York, New York County, United States', 'rank': {'importance': 0.3903352193791242, 'popularity': 8.615793062435909}, 'place_id': '517af9dda2c87e52c059829f820d19624440f00102f9012e53960f00000000c0020192031243656e7472616c205061726b20546f776572', 'bbox': {'lon1': -73.9814245, 'lat1': 40.7660436, 'lon2': -73.9805426, 'lat2': 40.7667831}}], 'query': {'lat': 40.7663935, 'lon': -73.9809909, 'plus_code': '87G8Q289+HJ'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '10312', 'district': 'Woodrow', 'suburb': 'Staten Island', 'street': 'Sinclair Avenue', 'housenumber': '620', 'lon': -74.19611889999999, 'lat': 40.5418055, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '620 Sinclair Avenue, New York, NY 10312, United States of America', 'address_line1': '620 Sinclair Avenue', 'address_line2': 'New York, NY 10312, United States of America', 'category': 'building.residential', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G7GRR3+PH', 'plus_code_short': 'GRR3+PH New York, New York, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 5.627104045481281}, 'place_id': '51286849368d8c52c0597fa5f3e159454440f00102f901f53dcc0e00000000c00203', 'bbox': {'lon1': -74.1961968, 'lat1': 40.54173, 'lon2': -74.196041, 'lat2': 40.541881}}], 'query': {'lat': 40.5418051, 'lon': -74.1961086, 'plus_code': '87G7GRR3+PH'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'King Cole Bar', 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'county': 'New York County', 'city': 'New York', 'postcode': '10022', 'district': 'Manhattan Community Board 5', 'suburb': 'Manhattan', 'street': 'East 55th Street', 'housenumber': '2', 'lon': -73.9744256, 'lat': 40.7613571, 'state_code': 'NY', 'distance': 16.406298860530914, 'result_type': 'amenity', 'formatted': 'King Cole Bar, 2 East 55th Street, New York, NY 10022, United States of America', 'address_line1': 'King Cole Bar', 'address_line2': '2 East 55th Street, New York, NY 10022, United States of America', 'category': 'catering.bar', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8Q26G+G6', 'plus_code_short': 'Q26G+G6 New York, New York County, United States', 'rank': {'importance': 0.13542022266142387, 'popularity': 9.615793062435909}, 'place_id': '', 'bbox': {'lon1': -73.9744756, 'lat1': 40.7613071, 'lon2': -73.9743756, 'lat2': 40.7614071}}], 'query': {'lat': 40.7613979, 'lon': -73.9746128, 'plus_code': '87G8Q26G+H5'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'county': 'New York County', 'city': 'New York', 'postcode': '10065', 'district': 'Manhattan Community Board 8', 'suburb': 'Manhattan', 'street': 'East 64th Street', 'housenumber': '5', 'lon': -73.96986153772039, 'lat': 40.76722655, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '5 East 64th Street, New York, NY 10065, United States of America', 'address_line1': '5 East 64th Street', 'address_line2': 'New York, NY 10065, United States of America', 'category': 'building', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8Q28J+V3', 'plus_code_short': 'Q28J+V3 New York, New York County, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 8.23054047932472}, 'place_id': '51128a2036127e52c059bb6fc67a34624440f00102f9019e05e80f00000000c00203', 'bbox': {'lon1': -73.9699789, 'lat1': 40.7671302, 'lon2': -73.9697367, 'lat2': 40.7673468}}], 'query': {'lat': 40.7672235, 'lon': -73.9698561, 'plus_code': '87G8Q28J+V3'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '11238', 'district': 'Kings County', 'suburb': 'Brooklyn', 'street': 'Park Place', 'housenumber': '584', 'lon': -73.95870660811059, 'lat': 40.6743703, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '584 Park Place, New York, NY 11238, United States of America', 'address_line1': '584 Park Place', 'address_line2': 'New York, NY 11238, United States of America', 'category': 'building', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8M2FR+PG', 'plus_code_short': 'M2FR+PG New York, New York, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 7.4140952844923795}, 'place_id': '51d212f6725b7d52c05965f217c451564440f00102f901a296ed0e00000000c00203', 'bbox': {'lon1': -73.9587639, 'lat1': 40.6742964, 'lon2': -73.9586493, 'lat2': 40.6744443}}], 'query': {'lat': 40.6743632, 'lon': -73.9587248, 'plus_code': '87G8M2FR+PG'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'county': 'New York County', 'city': 'New York', 'postcode': '10027', 'district': 'Manhattan Community Board 10', 'suburb': 'Manhattan', 'street': 'West 126th Street', 'housenumber': '157', 'lon': -73.94682989155604, 'lat': 40.8094184, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '157 West 126th Street, New York, NY 10027, United States of America', 'address_line1': '157 West 126th Street', 'address_line2': 'New York, NY 10027, United States of America', 'category': 'building', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8R353+Q7', 'plus_code_short': 'R353+Q7 New York, New York County, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 7.773908107268586}, 'place_id': '51f0c666dc987c52c059ec63aa059b674440f00102f901dd73331000000000c00203', 'bbox': {'lon1': -73.9469043, 'lat1': 40.8093401, 'lon2': -73.9467555, 'lat2': 40.8094966}}], 'query': {'lat': 40.809448, 'lon': -73.946777, 'plus_code': '87G8R353+Q7'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '10304', 'district': 'Todt Hill', 'suburb': 'Staten Island', 'street': 'Benedict Road', 'housenumber': '177', 'lon': -74.10640072576686, 'lat': 40.59498545, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '177 Benedict Road, New York, NY 10304, United States of America', 'address_line1': '177 Benedict Road', 'address_line2': 'New York, NY 10304, United States of America', 'category': 'building', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G7HVVV+XC', 'plus_code_short': 'HVVV+XC New York, New York, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 5.816090493512867}, 'place_id': '511e5cfd44cf8652c05945acb47b284c4440f00102f9019a11c10e00000000c00203', 'bbox': {'lon1': -74.106667, 'lat1': 40.5947786, 'lon2': -74.1062232, 'lat2': 40.5951981}}], 'query': {'lat': 40.5950017, 'lon': -74.1064235, 'plus_code': '87G7HVWV+2C'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'The Brittany', 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '10473', 'district': 'Bronx County', 'suburb': 'The Bronx', 'street': 'Morrison Avenue', 'housenumber': '875', 'lon': -73.87344843797473, 'lat': 40.821653999999995, 'state_code': 'NY', 'distance': 44.950786140330436, 'result_type': 'amenity', 'county': 'Bronx County', 'formatted': 'The Brittany, 875 Morrison Avenue, New York, NY 10473, United States of America', 'address_line1': 'The Brittany', 'address_line2': '875 Morrison Avenue, New York, NY 10473, United States of America', 'category': 'building.residential', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8R4CG+MJ', 'plus_code_short': 'R4CG+MJ New York, Bronx County, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 6.386696825259782}, 'place_id': '5100f64694e67752c059545051f52b694440f00102f901a73cd01000000000c0020192030c546865204272697474616e79e203216f70656e7374726565746d61703a76656e75653a7761792f323832303832343731', 'bbox': {'lon1': -73.8735552, 'lat1': 40.8213085, 'lon2': -73.8733413, 'lat2': 40.8220286}}], 'query': {'lat': 40.8215857, 'lon': -73.8740892, 'plus_code': '87G8R4CG+J9'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '11230', 'district': 'Kings County', 'neighbourhood': 'Midwood', 'suburb': 'Brooklyn', 'street': 'Ocean Parkway', 'housenumber': '1350', 'lon': -73.96955226103896, 'lat': 40.6157254, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '1350 Ocean Parkway, New York, NY 11230, United States of America', 'address_line1': '1350 Ocean Parkway', 'address_line2': 'New York, NY 11230, United States of America', 'category': 'building.residential', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8J28J+75', 'plus_code_short': 'J28J+75 New York, New York, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 6.9447330302955965}, 'place_id': '51363bed240d7e52c05984280417d04e4440f00102f901f6e1d80e00000000c00203', 'bbox': {'lon1': -73.9698935, 'lat1': 40.6155396, 'lon2': -73.9693404, 'lat2': 40.6159182}}], 'query': {'lat': 40.6157378, 'lon': -73.9696944, 'plus_code': '87G8J28J+74'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '10451', 'district': 'Bronx County', 'suburb': 'The Bronx', 'street': 'Grand Concourse', 'housenumber': '800', 'lon': -73.92260592736525, 'lat': 40.82486205, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '800 Grand Concourse, New York, NY 10451, United States of America', 'address_line1': '800 Grand Concourse', 'address_line2': 'New York, NY 10451, United States of America', 'category': 'building', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8R3FG+WX', 'plus_code_short': 'R3FG+WX New York, New York, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 7.439462329032323}, 'place_id': '514a48bbf90b7b52c059133b641495694440f00102f9017cef681000000000c00203', 'bbox': {'lon1': -73.9235868, 'lat1': 40.8244607, 'lon2': -73.9224275, 'lat2': 40.8252613}}], 'query': {'lat': 40.8248699, 'lon': -73.9229829, 'plus_code': '87G8R3FG+WR'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '10303', 'district': 'Graniteville', 'suburb': 'Staten Island', 'street': 'Van Name Avenue', 'housenumber': '456', 'lon': -74.15530325, 'lat': 40.6249942, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '456 Van Name Avenue, New York, NY 10303, United States of America', 'address_line1': '456 Van Name Avenue', 'address_line2': 'New York, NY 10303, United States of America', 'category': 'building.residential', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G7JRFV+XV', 'plus_code_short': 'JRFV+XV New York, New York, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 5.9275976074387735}, 'place_id': '519aed0a7df08952c059489858cfff4f4440f00102f9015ab7e64700000000c00203', 'bbox': {'lon1': -74.1553847, 'lat1': 40.6249659, 'lon2': -74.1552218, 'lat2': 40.6250225}}], 'query': {'lat': 40.6249962, 'lon': -74.1553058, 'plus_code': '87G7JRFV+XV'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'Carlton House', 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '11372', 'suburb': 'Queens', 'street': '85th Street', 'housenumber': '34-41', 'lon': -73.88188184988164, 'lat': 40.75306875, 'state_code': 'NY', 'distance': 0, 'result_type': 'amenity', 'formatted': 'Carlton House, 34-41 85th Street, New York, NY 11372, United States of America', 'address_line1': 'Carlton House', 'address_line2': '34-41 85th Street, New York, NY 11372, United States of America', 'category': 'building', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8Q439+66', 'plus_code_short': 'Q439+66 New York, New York, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 7.120363687034358}, 'place_id': '515e0b92c0707852c059de718a8e64604440f00102f9013653d10e00000000c0020192030d4361726c746f6e20486f757365', 'bbox': {'lon1': -73.8820553, 'lat1': 40.7525098, 'lon2': -73.8815903, 'lat2': 40.7536085}}], 'query': {'lat': 40.7531191, 'lon': -73.8818757, 'plus_code': '87G8Q439+66'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'city': 'New York', 'postcode': '11373', 'suburb': 'Queens', 'street': 'Lamont Avenue', 'housenumber': '91-15', 'lon': -73.87461170549808, 'lat': 40.74381045, 'state_code': 'NY', 'distance': 0, 'result_type': 'building', 'formatted': '91-15 Lamont Avenue, New York, NY 11373, United States of America', 'address_line1': '91-15 Lamont Avenue', 'address_line2': 'New York, NY 11373, United States of America', 'category': 'building', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G8P4VG+G5', 'plus_code_short': 'P4VG+G5 New York, New York, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 7.152514652553668}, 'place_id': '5109f45fa3f97752c05926964a2e355f4440f00102f901e6f4f71000000000c00203', 'bbox': {'lon1': -73.8748463, 'lat1': 40.7435904, 'lon2': -73.8743771, 'lat2': 40.7440558}}], 'query': {'lat': 40.7438639, 'lon': -73.8745722, 'plus_code': '87G8P4VG+G5'}}
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'county': 'New York County', 'city': 'New York', 'postcode': '10014', 'district': 'West Village', 'suburb': 'Manhattan', 'street': 'Jane Street', 'housenumber': '61', 'lon': -74.0059082, 'lat': 40.7382224, 'state_code': 'NY', 'distance': 8.557509230398336, 'result_type': 'building', 'formatted': '61 Jane Street, New York, NY 10014, United States of America', 'address_line1': '61 Jane Street', 'address_line2': 'New York, NY 10014, United States of America', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G7PXQV+7J', 'plus_code_short': 'PXQV+7J New York, New York County, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 8.345342973211173}, 'place_id': '51ce71c9cc608052c0595a9654127e5e4440f00103f9010ee6239900000000c00203e2034c6f70656e6164647265737365733a616464726573733a75732f6e792f636974795f6f665f6e65775f796f726b2d6164647265737365732d636974793a30616538386133383234633233653937', 'bbox': {'lon1': -74.0059582, 'lat1': 40.7381724, 'lon2': -74.0058582, 'lat2': 40.7382724}}], 'query': {'lat': 40.7382981, 'lon': -74.0058899, 'plus_code': '87G7PXQV+8J'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 24
#      22 suburb = data['results'][0]['suburb']
#      23 postcode = data['results'][0]['postcode']
# ---> 24 category = data['results'][0]['category']
#      25 result_type = data['results'][0]['result_type']
#      26 state = data['results'][0]['state']
#
# KeyError: 'category'

# %%
for i in range(1, 400):
        response = requests.get('https://api.themoviedb.org/3/\
    movie/top_rated?api_key=aaa7de53dcab3a19afed86880\
    f364e54&language=en-US&page={}'.format(i))
        temp_df = pd.DataFrame(response.json()['results'])[['id',
                    'title', 'overview', 'release_date', 'popularity',
                       'vote_average', 'vote_count']]
        df = df.append(temp_df, ignore_index=True)
else:
    print('Error', response.status_code)
